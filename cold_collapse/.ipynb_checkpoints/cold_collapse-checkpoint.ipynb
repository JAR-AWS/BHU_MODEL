# %%
import yt
import matplotlib.pyplot as plt
import numpy as np

# set matplotlib formatting to be the same as yt
plt.rcParams['font.size'] = 14
plt.rcParams['font.family'] = 'serif'
plt.rcParams['mathtext.fontset'] = 'stix'

# %%
# load data from file
ds0 = yt.load('plt_1d_00000/', hint="castro")
ds1 = yt.load('plt_1d_02000/', hint="castro")
ds2 = yt.load('plt_1d_05000/', hint="castro")
ds3 = yt.load('plt_1d_08000/', hint="castro")
ds4 = yt.load('plt_1d_10000/', hint="castro")
ds5 = yt.load('plt_1d_11000/', hint="castro")
ds6 = yt.load('plt_1d_13000/', hint="castro")
ds7 = yt.load('plt_1d_14000/', hint="castro")
ds8 = yt.load('plt_1d_15500/', hint="castro")
ds9 = yt.load('plt_1d_16500/', hint="castro")
ds10 = yt.load('plt_1d_17500/', hint="castro")
ds11 = yt.load('plt_1d_18000/', hint="castro")
ds12 = yt.load('plt_1d_18100/', hint="castro")
ds13 = yt.load('plt_1d_18200/', hint="castro")
ds14 = yt.load('plt_1d_18248/', hint="castro")

data = [ds0, ds1, ds2, ds3, ds4, ds5, ds6, ds7, ds8, ds9, ds10, ds11, ds12, ds13, ds14]
# Out:
# yt : [INFO     ] 2024-05-21 17:57:08,531 Parameters: current_time              = 0.0
# yt : [INFO     ] 2024-05-21 17:57:08,534 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:08,553 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:08,554 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:08,596 Parameters: current_time              = 0.00756916742846107
# yt : [INFO     ] 2024-05-21 17:57:08,596 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:08,597 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:08,597 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:08,654 Parameters: current_time              = 0.0186755513973338
# yt : [INFO     ] 2024-05-21 17:57:08,656 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:08,668 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:08,671 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:08,726 Parameters: current_time              = 0.0291260125719732
# yt : [INFO     ] 2024-05-21 17:57:08,735 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:08,742 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:08,747 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:08,785 Parameters: current_time              = 0.0355176410037897
# yt : [INFO     ] 2024-05-21 17:57:08,795 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:08,803 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:08,807 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:08,865 Parameters: current_time              = 0.0385490029808558
# yt : [INFO     ] 2024-05-21 17:57:08,868 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:08,869 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:08,870 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:08,909 Parameters: current_time              = 0.0442107329404793
# yt : [INFO     ] 2024-05-21 17:57:08,915 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:08,918 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:08,922 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:08,976 Parameters: current_time              = 0.0466678340449039
# yt : [INFO     ] 2024-05-21 17:57:08,977 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:08,978 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:08,979 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:09,029 Parameters: current_time              = 0.0497259312569461
# yt : [INFO     ] 2024-05-21 17:57:09,031 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:09,032 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:09,033 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:09,072 Parameters: current_time              = 0.0513887737510704
# yt : [INFO     ] 2024-05-21 17:57:09,073 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:09,074 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:09,075 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:09,127 Parameters: current_time              = 0.052693630724623
# yt : [INFO     ] 2024-05-21 17:57:09,130 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:09,132 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:09,135 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:09,179 Parameters: current_time              = 0.0531339796984801
# yt : [INFO     ] 2024-05-21 17:57:09,180 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:09,181 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:09,182 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:09,228 Parameters: current_time              = 0.0531966187563172
# yt : [INFO     ] 2024-05-21 17:57:09,229 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:09,230 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:09,231 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:09,285 Parameters: current_time              = 0.0532470067166953
# yt : [INFO     ] 2024-05-21 17:57:09,286 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:09,287 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:09,288 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]
# yt : [INFO     ] 2024-05-21 17:57:09,333 Parameters: current_time              = 0.0532659376701098
# yt : [INFO     ] 2024-05-21 17:57:09,334 Parameters: domain_dimensions         = [10240     1     1]
# yt : [INFO     ] 2024-05-21 17:57:09,334 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-05-21 17:57:09,335 Parameters: domain_right_edge         = [3.e+08 1.e+00 1.e+00]

# %%
ds0.derived_field_list   # list of quantities that can be plotted
# Out:
# [('boxlib', 'Temp'),
#  ('boxlib', 'cell_volume'),
#  ('boxlib', 'density'),
#  ('boxlib', 'dphi'),
#  ('boxlib', 'dr'),
#  ('boxlib', 'dtheta'),
#  ('boxlib', 'grav_x'),
#  ('boxlib', 'grav_y'),
#  ('boxlib', 'grav_z'),
#  ('boxlib', 'path_element_phi'),
#  ('boxlib', 'path_element_r'),
#  ('boxlib', 'path_element_theta'),
#  ('boxlib', 'phi'),
#  ('boxlib', 'phiGrav'),
#  ('boxlib', 'r'),
#  ('boxlib', 'rho_C12'),
#  ('boxlib', 'rho_E'),
#  ('boxlib', 'rho_Mg24'),
#  ('boxlib', 'rho_O16'),
#  ('boxlib', 'rho_e'),
#  ('boxlib', 'theta'),
#  ('boxlib', 'volume'),
#  ('boxlib', 'xmom'),
#  ('boxlib', 'ymom'),
#  ('boxlib', 'zmom'),
#  ('gas', 'averaged_density'),
#  ('gas', 'cell_mass'),
#  ('gas', 'cell_volume'),
#  ('gas', 'density'),
#  ('gas', 'density_gradient_magnitude'),
#  ('gas', 'density_gradient_phi'),
#  ('gas', 'density_gradient_r'),
#  ('gas', 'density_gradient_theta'),
#  ('gas', 'dphi'),
#  ('gas', 'dr'),
#  ('gas', 'dtheta'),
#  ('gas', 'dynamical_time'),
#  ('gas', 'jeans_mass'),
#  ('gas', 'kT'),
#  ('gas', 'mass'),
#  ('gas', 'mean_molecular_weight'),
#  ('gas', 'momentum_density_phi'),
#  ('gas', 'momentum_density_r'),
#  ('gas', 'momentum_density_theta'),
#  ('gas', 'number_density'),
#  ('gas', 'path_element_phi'),
#  ('gas', 'path_element_r'),
#  ('gas', 'path_element_theta'),
#  ('gas', 'phi'),
#  ('gas', 'r'),
#  ('gas', 'temperature'),
#  ('gas', 'theta'),
#  ('gas', 'total_energy_density'),
#  ('gas', 'volume'),
#  ('index', 'cell_volume'),
#  ('index', 'dphi'),
#  ('index', 'dr'),
#  ('index', 'dtheta'),
#  ('index', 'grid_indices'),
#  ('index', 'grid_level'),
#  ('index', 'ones'),
#  ('index', 'path_element_phi'),
#  ('index', 'path_element_r'),
#  ('index', 'path_element_theta'),
#  ('index', 'phi'),
#  ('index', 'r'),
#  ('index', 'theta'),
#  ('index', 'virial_radius_fraction'),
#  ('index', 'volume'),
#  ('index', 'zeros')]

# %%
# set the initial density and initial radius
rho0 = 2.8e8 * yt.units.g / yt.units.cm**3
r0 = 2.39e8 * yt.units.cm  # initial radius, equivalent to 100Rs
rb = 3e8 * yt.units.cm  # box size
gamma = 1.666666  # adiabatic index for monoatomic gas

G = 6.67428e-8      # Gravitational constant in cgs units
c = 2.99e10         # Speed of light in cgs units
M = 16e33   # in grams, equivalent to 8 solar mass
Rs = 2 * G * M / c ** 2     # Gravitational radius/ Schwarzschild radius
Rs = Rs * yt.units.cm      # add  units to the Gravitational radius
u0 = np.sqrt(Rs / r0) * c  # initial velocity
u0 = u0 * yt.units.cm/yt.units.s
tc = 0.05326593767010977 * yt.units.s     # collapse timescale
rm = rb/Rs     # set the extrema

NB = 10240    # number of bins or resolution

# %%
# define a function to convert radius into the required unit
def my_r(field, data):
    return data['gas', 'r']/Rs

# define a function to convert density into the required unit
def my_density(field, data):
    return data['gas', 'density']/rho0

# define a function to convert momentum density into the required unit
def my_momentum(field, data):
    return np.abs(data['boxlib', 'xmom'])/(rho0 * u0)

# define a function to calculate and convert velocity into the required unit
def my_velocity(field, data):
    return (data['boxlib', 'xmom']) / (data['gas', 'density'] * c * (yt.units.cm / yt.units.s))

# %%
# Plotting the density profile

T = []   # stores the time elapsed
D = []   # stores the central density of each profile
profiles_dens = []  # stores the density profiles to be plotted
labels_dens = []   # stores the labels for each of the profiles


for ds in data:
    
    my_sphere = ds.sphere([0.0, 0.0, 0.0], rb)  # define a sphere centered at (0, 0, 0) with radius rb containing the dataset
    
    # add a new density field with the required units
    ds.add_field(("gas", "my_density"), units="dimensionless", function=my_density, sampling_type='cell', force_override=True)
    # add a new radius field with the required units
    ds.add_field(("gas", "my_r"), units="dimensionless", function=my_r, sampling_type='cell', force_override=True)
    # create a density profile with the newly defined density and radius fields
    profile = yt.create_profile(
    data_source=my_sphere,
    bin_fields=[("gas", "my_r")],
    fields=[("gas", "my_density")],
    n_bins=NB,
    units=dict(my_r="dimensionless", my_density="dimensionless"),
    logs=dict(my_r=False),
    weight_field=None,
    extrema=dict(my_r=(0, rm)),
    )
    profiles_dens.append(profile)
    labels_dens.append(rf"t = {ds.current_time.value/tc.value:.5f} $t_c$")
    for i in range(1, len(profile[('gas', 'my_density')])):
        if profile[('gas', 'my_density')][i] < 0.5*profile[('gas', 'my_density')][i-1]:
            decreasing_density_location = profile.x[i]
            break
    T.append(ds.current_time.value/tc.value)
    D.append((profile[('gas', 'my_density')])[0])

plot = yt.ProfilePlot.from_profiles(profiles=profiles_dens, labels=labels_dens)
plot.set_xlabel(r"$r/r_S$")
plot.set_ylabel("my_density", r"$\rho/\rho_0$")
plot.set_log("my_density", True)
plot.set_log("my_r", True)
plot.annotate_title(r"Density profile ($R = 100R_S$, Gamma Law EOS ($p=0$))")
# plot.save()
plot.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
# Calculate the mass of each of the shells
mass_shell = np.zeros([len(profiles_dens), len(profiles_dens[0][("gas", "my_density")])])
for i in range(len(profiles_dens)):
    for j in range(len(np.asarray(profiles_dens[i][("gas", "my_density")]))):
        mass_shell[i, j] = np.abs(np.asarray(profiles_dens[i][("gas", "my_density")])[j] * rho0.value * (4./3.)*np.pi*((((profiles_dens[i].x)[j]*Rs.value)**3) 
                            - (((profiles_dens[i].x)[j-1]*Rs.value)**3)))
        mass_shell[i, 0] = 0
r_shell = np.asarray(profiles_dens[0].x) # radial coordinate of each shell

# %%
indx = [] # stores the indices of the location of radius
radius = np.zeros([len(profiles_dens)])  # array to store radius
massin = np.zeros([len(profiles_dens), len(profiles_dens[0][("gas", "my_density")])])  # array to store enclosed mass

# calculate radius (note that for this case the radius is the location of the maximum mass shell)

for i in range(len(profiles_dens)):
    for j in range(len(mass_shell[i, :])):
        if mass_shell[i, j] == np.max(mass_shell[i, :]):
            radius[i] = (profiles_dens[i].x)[j]
            indx.append(j)

R = radius

# calculate the enclosed mass

for i in range(len(profiles_dens)):
    for j in range(len(mass_shell[i, :])):
        # if mass_shell[i, j] == np.max(mass_shell[i, :]): 
        #     break
        massin[i, j] = np.sum(mass_shell[i, :j])

TM = []
for i in range(len(profiles_dens)):
    TM.append(np.max(massin[i, -1])/2e33)

# %%
with plt.style.context("yt.default"):
    fig, ax = plt.subplots(figsize=(10,8))
    for i in range(len(profiles_dens[:])):
        ax.plot(r_shell, (massin[i, :])/2e33, label=labels_dens[i])

    ax.set_xlabel(r"$r/r_S$")
    ax.set_ylabel(r"$M_{shell}/M_\odot$")
    ax.set_title(r"Mass of each shell")
    ax.set_yscale("log")
    ax.set_xscale("log")
    ax.set_xlim(3.1e-2,2e2)
    ax.legend(loc="lower right")
    ax.grid()
    fig.subplots_adjust(left=0.12, right=0.9, bottom=0.1, top=0.9, wspace=0.2, hspace=0.2)
plt.show()

# %%
x = np.linspace(-0.05, 1.05, 1000)
y = x  # denotes r=r_s

with plt.style.context("yt.default"):
    fig, ax = plt.subplots(figsize=(10,8))
    for i in range(len(profiles_dens[:])):
        ax.plot(r_shell, (2*G*(massin[i, :])/c**2)/Rs.value, label=labels_dens[i])

    ax.plot(x, y, "k--", label=r"$r=r_s$")
    ax.set_xlabel(r"$r/r_{s0}$")
    ax.set_ylabel(r"$r_s/r_{s0}$")
    ax.set_title(r"$r_s$ vs $r$")
    # ax.set_yscale("log")
    ax.set_xscale("log")
    ax.set_xlim(3.1e-2,2e2)
    ax.legend(loc="lower right")
    ax.grid()
    fig.subplots_adjust(left=0.12, right=0.9, bottom=0.1, top=0.9, wspace=0.2, hspace=0.2)
plt.show()

# %%
def R_FLRW(R0,steps,plot=False):
    """Inputs: radius R0 in units of Rs and number of time steps
      Outputs: t ad R(t) for flat FLRW metric
    """
    tc=2/3*np.sqrt(R0**3)   # collapse time
    t=np.arange(0,tc,tc/steps)
    tr=tc-t  # time remaing to singular collapse
    tBH=tc-2/3.  # time to BH collapse
    R=(3/2*tr)**(2/3.)  # in units of Rs
    rho=(R0/R)**3    # rho/rho0
    if (plot):
        plt.plot(t/tc,R,"-",alpha=1,lw=2,label='$R/R_s$ for $R_0=$'+str(np.around(R0,2))+"$R_s$"+"\nFLRW k=0", zorder=0)       
    return t,R
t1,R1 = R_FLRW(100,1000.,plot=True)

plt.scatter(T, R, color="r", label="simulation", zorder=1)
plt.ylabel(r"$r/r_S$")
plt.xlabel(r"$t/t_c$")
plt.legend()
plt.grid()
plt.title('Radius vs time for Gamma law EOS')
plt.show()

# %%
def R_FLRW(R0,steps,plot=False):
    """Inputs: radius R0 in units of Rs and number of time steps
      Outputs: t ad rho(t) for flat FLRW metric
    """
    tc=2/3*np.sqrt(R0**3)   # collapse time
    t=np.arange(0,tc,tc/steps)
    tr=tc-t  # time remaing to singular collapse
    tBH=tc-2/3.  # time to BH collapse
    R=(3/2*tr)**(2/3.)  # in units of Rs
    rho=(R0/R)**3    # rho/rho0
    if (plot):
        plt.plot(t/tc,rho,":",alpha=0.5,lw=3,label=r'$\rho$ for $R_0=$'+str(np.around(R0,2))+"$R_s$""\nFLRW k=0", zorder=0)         
    return t,R
t1,R1 = R_FLRW(100,1000.,plot=True)
plt.scatter(T[:], D[:], color="r", label="Simulation", zorder=1)
plt.xlabel(r'$t/t_c$')
plt.ylabel(r'$\rho/\rho_0$')
plt.yscale('log')
plt.legend()
plt.grid()
plt.title('Density vs time for gamma law EOS')
plt.show()

# %%
profiles = []
labels = []
mom = []
tmom = []


for ds in data:
    # add a new density field with the required units
    ds.add_field(("boxlib", "my_momentum"), units="dimensionless", function=my_momentum, sampling_type='cell', force_override=True)
    # add a new radius field with the required units
    ds.add_field(("gas", "my_r"), units="dimensionless", function=my_r, sampling_type='cell', force_override=True)
    my_sphere = ds.sphere([0.0, 0.0, 0.0], rb)
    profile = yt.create_profile(
    data_source=my_sphere,
    bin_fields=[("gas", "my_r")],
    fields=[("boxlib", "my_momentum")],
    n_bins=NB,
    units=dict(my_r="dimensionless", my_momentum="dimensionless"),
    logs=dict(my_r=False, my_momentum=False),
    weight_field=None,
    extrema=dict(my_r=(0, rm)),
    )
    profiles.append(profile)
    labels.append(rf"t = {ds.current_time.value/tc.value:.5f} $t_c$")
    tmom.append(ds.current_time.value/tc.value)
    mom.append(np.max(profile[('boxlib', 'my_momentum')]).value)
plot = yt.ProfilePlot.from_profiles(profiles, labels=labels)
plot.set_xlabel(r"$r/r_S$")
plot.set_ylabel("my_momentum", r"$\rho u/\rho_0 u_0$")
plot.set_log("my_momentum", True)
plot.set_log("my_r", True)
plot.annotate_title(r"Momentum profile for Gamma Law EOS")
plot.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
profiles = []
labels = []


for ds in data:
    # add a new density field with the required units
    ds.add_field(("boxlib", "my_velocity"), units="dimensionless", function=my_velocity, sampling_type='cell', force_override=True)
    # add a new radius field with the required units
    ds.add_field(("gas", "my_r"), units="dimensionless", function=my_r, sampling_type='cell', force_override=True)
    my_sphere = ds.sphere([0.0, 0.0, 0.0], rb)
    profile = yt.create_profile(
    data_source=my_sphere,
    bin_fields=[("gas", "my_r")],
    fields=[("boxlib", "my_velocity")],
    n_bins=NB,
    units=dict(my_r="dimensionless", my_velocity="dimensionless"),
    logs=dict(my_r=False, my_velocity=False),
    weight_field=None,
    extrema=dict(my_r=(0, rm)),
    )
    profiles.append(profile)
    labels.append(rf"t = {ds.current_time.value/tc.value:.5f} $t_c$")
    
plot = yt.ProfilePlot.from_profiles(profiles, labels=labels)
plot.set_xlabel(r"$r/r_S$")
plot.set_ylabel("my_velocity", r"$u/c$")
plot.annotate_title(r"Velocity profile for Gamma Law EOS")
plot.set_log("my_velocity", False)
plot.set_log("my_r", True)
plot.show()
# Out:
# /home/codes/Note/jupy/lib/python3.10/site-packages/yt/visualization/profile_plotter.py:403: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   axes.set_yscale(yscale)
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
